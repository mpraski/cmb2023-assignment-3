# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.dates as mdates

# %%
df = pd.read_csv('wlan_probe_requests_2.csv')
df_responses = pd.read_csv('wlan_probe_responses_2.csv')

# %%
df.head()
# Out:
#     No.       Time             Source Destination  Protocol  Length  \
# 0   744  21.833491  a2:34:0b:46:0e:c8   Broadcast    802.11     169
# 1   751  21.849308  a2:34:0b:46:0e:c8   Broadcast    802.11     169
# 2  1244  30.137038  06:b9:45:0b:8f:c8   Broadcast    802.11     156
# 3  1249  30.148576  06:b9:45:0b:8f:c8   Broadcast    802.11     156
# 4  1546  36.664904  8e:6b:87:17:3c:76   Broadcast    802.11      82
#
#                                                 Info
# 0  Probe Request, SN=227, FN=0, Flags=........C, ...
# 1  Probe Request, SN=228, FN=0, Flags=........C, ...
# 2  Probe Request, SN=2548, FN=0, Flags=........C,...
# 3  Probe Request, SN=2549, FN=0, Flags=........C,...
# 4  Probe Request, SN=89, FN=0, Flags=........C, S...

# %%
ax = df.pivot(columns="Source")["Time"].plot(kind="hist", stacked=True, bins=80, legend=False)
ax.set_xlabel("Time")
ax.set_ylabel("Probe Req Frequency")
# Out:
# Text(0, 0.5, 'Probe Req Frequency')

# %%
df["Source"].nunique()
# Out:
# 105

# %%
df[~df['Source'].str.contains(r'^([0-9A-Fa-f]{2}[:-]){5}([0-9A-Fa-f]{2})$')]['Source'].unique()
# Out:
# /var/folders/sg/vb52j6vx5gxgln4xc69djkp80000gn/T/ipykernel_7635/2513569437.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[~df['Source'].str.contains(r'^([0-9A-Fa-f]{2}[:-]){5}([0-9A-Fa-f]{2})$')]['Source'].unique()
# array(['AzureWaveTec_9c:2a:f3', 'LiteonTechno_13:23:c1',
#        'SagemcomBroa_d7:48:32', 'MS-NLB-PhysServer-23_80:b3:74:d5',
#        'Google_02:02:02', 'Google_c0:c0:c0', 'Google_72:72:72'],
#       dtype=object)

# %%
ax = df_responses.pivot(columns="Source")["Time"].plot(kind="hist", stacked=True, bins=80, legend=False)
ax.set_xlabel("Time")
ax.set_ylabel("Probe Resp Frequency")
# Out:
# Text(0, 0.5, 'Probe Resp Frequency')
