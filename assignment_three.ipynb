# %%
import os
import json
import folium
import requests
import pandas as pd
import pycountry_convert as pc
import numpy as np
from statistics import mean 
from pandas import json_normalize
from sklearn.cluster import KMeans
from datetime import datetime, timedelta
from ripe.atlas.cousteau import (
    Ping,
    Traceroute,
    AtlasSource,
    AtlasCreateRequest,
    AtlasResultsRequest
)
from dotenv import load_dotenv

# Load env variables
# You need to set the ATLAS_API_KEY to make Atlas API requestrs
# and optionally IP_STACK_ACCESS_KEY if you want to geolocate the data center IP addresses
load_dotenv()
# Out:
# True

# %%
df = pd.read_csv('cloudregions.csv', names=["Endpoint", "Provider", "State", "City", "Country", "IP"])

# %%
df.head()
# Out:
#                                    Endpoint Provider          State  \
# 0  https://ec2.us-east-1.amazonaws.com/ping      AWS    N. Virginia
# 1  https://ec2.us-east-2.amazonaws.com/ping      AWS           Ohio
# 2  https://ec2.us-west-1.amazonaws.com/ping      AWS  N. California
# 3                                       NaN      AWS  N. California
# 4  https://ec2.us-west-2.amazonaws.com/ping      AWS         Oregon
#
#             City        Country              IP
# 0        Ashburn  United States   52.46.142.79;
# 1       Columbus  United States  99.78.176.246;
# 2  San Francisco  United States  176.32.118.30;
# 3  San Francisco  United States              0;
# 4       Portland  United States   52.94.214.88;

# %%
# Clean up the IP address
df["IP"] = df["IP"].str[:-1]

# %%
df.head()
# Out:
#                                    Endpoint Provider          State  \
# 0  https://ec2.us-east-1.amazonaws.com/ping      AWS    N. Virginia
# 1  https://ec2.us-east-2.amazonaws.com/ping      AWS           Ohio
# 2  https://ec2.us-west-1.amazonaws.com/ping      AWS  N. California
# 3                                       NaN      AWS  N. California
# 4  https://ec2.us-west-2.amazonaws.com/ping      AWS         Oregon
#
#             City        Country             IP
# 0        Ashburn  United States   52.46.142.79
# 1       Columbus  United States  99.78.176.246
# 2  San Francisco  United States  176.32.118.30
# 3  San Francisco  United States              0
# 4       Portland  United States   52.94.214.88

# %%
# Define a function to make HTTP requests
def make_request(row):
    IP_STACK_ACCESS_KEY = os.getenv('IP_STACK_ACCESS_KEY')
    
    if row['IP'] == "0":
        return json.dumps("{}")

    url = f"http://api.ipstack.com/{row['IP']}?access_key={IP_STACK_ACCESS_KEY}"

    try:
        response = requests.get(url)
        print(f"URL: {url}, Status Code: {response.status_code}")
        return response.json()
    except Exception as e:
        print(f"Error for URL {url}: {e}")
        return None
    
def geolocate_ip(df):
    # Make IP geolocation requests for the cloud data centers
    df['geo_response'] = df.apply(make_request, axis=1)
    
    # Explode the JSON response into separate columns
    df_normalized = json_normalize(df['geo_response'])
    
    # Concat with the original frame
    df_result = pd.concat([df, df_normalized], axis=1)
    
    # Filter out those centers for which geolocation failed
    df_result_nonna = df_result[df_result['latitude'].notna()]
    
    return df_result_nonna

# %%
# Originally: df_result_nonna = geolocate_ip(df); df_result_nonna.to_csv('cloud_regions_geocoded.csv')
df_result_nonna = pd.read_csv('cloud_regions_geocoded.csv')

# %%
df_result_nonna.head()
# Out:
#    Unnamed: 0                                  Endpoint Provider  \
# 0           0  https://ec2.us-east-1.amazonaws.com/ping      AWS
# 1           1  https://ec2.us-east-2.amazonaws.com/ping      AWS
# 2           2  https://ec2.us-west-1.amazonaws.com/ping      AWS
# 3           4  https://ec2.us-west-2.amazonaws.com/ping      AWS
# 4           5  https://ec2.ap-east-1.amazonaws.com/ping      AWS
#
#            State           City        Country             IP  \
# 0    N. Virginia        Ashburn  United States   52.46.142.79
# 1           Ohio       Columbus  United States  99.78.176.246
# 2  N. California  San Francisco  United States  176.32.118.30
# 3         Oregon       Portland  United States   52.94.214.88
# 4      Hong Kong      Hong Kong      Hong Kong  13.248.32.123
#
#                                         geo_response             ip  type  \
# 0  {'ip': '52.46.142.79', 'type': 'ipv4', 'contin...   52.46.142.79  ipv4
# 1  {'ip': '99.78.176.246', 'type': 'ipv4', 'conti...  99.78.176.246  ipv4
# 2  {'ip': '176.32.118.30', 'type': 'ipv4', 'conti...  176.32.118.30  ipv4
# 3  {'ip': '52.94.214.88', 'type': 'ipv4', 'contin...   52.94.214.88  ipv4
# 4  {'ip': '13.248.32.123', 'type': 'ipv4', 'conti...  13.248.32.123  ipv4
#
#    ...                                 location.languages  \
# 0  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 1  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 2  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 3  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 4  ...  [{'code': 'zh', 'name': 'Chinese', 'native': '...
#
#                      location.country_flag location.country_flag_emoji  \
# 0  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 1  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 2  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 3  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 4  https://assets.ipstack.com/flags/hk.svg                          🇭🇰
#
#   location.country_flag_emoji_unicode location.calling_code location.is_eu  \
# 0                     U+1F1FA U+1F1F8                     1          False
# 1                     U+1F1FA U+1F1F8                     1          False
# 2                     U+1F1FA U+1F1F8                     1          False
# 3                     U+1F1FA U+1F1F8                     1          False
# 4                     U+1F1ED U+1F1F0                   852          False
#
#   success error.code  error.type  error.info
# 0     NaN        NaN         NaN         NaN
# 1     NaN        NaN         NaN         NaN
# 2     NaN        NaN         NaN         NaN
# 3     NaN        NaN         NaN         NaN
# 4     NaN        NaN         NaN         NaN
#
# [5 rows x 32 columns]

# %%
# Prepare a map
map_center = [df_result_nonna['latitude'].mean(), df_result_nonna['longitude'].mean()]
map_object = folium.Map(location=map_center, zoom_start=5)

# %%
# Add markers for each row in the DataFrame
for index, row in df_result_nonna.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Endpoint']
    ).add_to(map_object)

map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e3d3674abac3bd1b01a202303d2e748 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e3d3674abac3bd1b01a202303d2e748&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e3d3674abac3bd1b01a202303d2e748 = L.map(
#                 &quot;map_7e3d3674abac3bd1b01a202303d2e748&quot;,
#                 {
#                     center: [25.957980188992945, 30.537745338265257],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac79d5ab000d1e96a8771f5e21099235 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ac79d5ab000d1e96a8771f5e21099235.addTo(map_7e3d3674abac3bd1b01a202303d2e748);
#
#
#             var marker_9b4b6371407355e0667679b31015f57c = L.marker(
#                 [39.043701171875, -77.47419738769531],
#                 {}
#             ).addTo(map_7e3d3674abac3bd1b01a202303d2e748);
#
#
#         var popup_a79865ea076fcf0360337dc0a2f91b72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1248252219eb7f0bc32727cc71333ee1 = $(`&lt;div id=&quot;html_1248252219eb7f0bc32727cc71333ee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_a79865ea076fcf0360337dc0a2f91b72.setContent(html_1248252219eb7f0bc32727cc71333ee1);
#
#
#
#         marker_9b4b6371407355e0667679b31015f57c.bindPopup(popup_a79865ea076fcf0360337dc0a2f91b72)
#         ;
#
#
#
#
#             var marker_0c5254d242255d97ee653517c4543c12 = L.marker(
#                 [39.99557876586914, -82.99945831298828],
#                 {}
#             ).addTo(map_7e3d3674abac3bd1b01a202303d2e748);
#
#
#         var popup_cd5a25b3d3a9c0332354091ea64483e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87eb35b2caea5b4b95ed608cecc951a1 = $(`&lt;div id=&quot;html_87eb35b2caea5b4b95ed608cecc951a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-east-2.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_cd5a25b3d3a9c0332354091ea64483e5.setContent(html_87eb35b2caea5b4b95ed608cecc951a1);
#
#
#
#         marker_0c5254d242255d97ee653517c4543c12.bindPopup(popup_cd5a25b3d3a9c0332354091ea64483e5)
#         ;
#
#
#
#
#             var marker_b17ed8466199a5dfbf4a8899fc703e99 = L.marker(
#                 [37.330528259277344, -121.83822631835938],
#                 {}
#             ).addTo(map_7e3d3674abac3bd1b01a202303d2e748);
#
#
#         var popup_6add2d013a7749c384f2bac580bdb549 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27ae6388bbb416105283f263e248c643 = $(`&lt;div id=&quot;html_27ae6388bbb416105283f263e248c643&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-west-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_6add2d013a7749c384f2bac580bdb549.setContent(html_27ae6388bbb416105283f263e248c643);
#
#
#
#         marker_b17ed8466199a5dfbf4a8899fc703e99.bindPopup(popup_6add2d013a7749c384f2bac580bdb549)
#         ;
#
#
#
#
#             var marker_70bb74021819cfbbedf0d1fba4b59a44 = L.marker(
#                 [45.83599853515625, -119.6989974975586],
#                 {}
#             ).addTo(map_7e3d3674abac3bd1b01a202303d2e748);
#
#
#         var popup_5bad9b644afd8ee48a0631ab41dd40ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e4823a759a55ebea45b8c10526df22b = $(`&lt;div id=&quot;html_6e4823a759a55ebea45b8c10526df22b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-west-2.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_5bad9b644afd8ee48a0631ab41dd40ef.setContent(html_6e4823a759a55ebea45b8c10526df22b);
#
#
#
#         marker_70bb74021819cfbbedf0d1fba4b59a44.bindPopup(popup_5bad9b644afd8ee48a0631ab41dd40ef)
#         ;
#
#
#
#
#             var marker_210bf20bd7e7a6ced070f6360414996a = L.marker(
#                 [22.248310089111328, 114.15239715576172],
#                 {}
#             ).addTo(map_7e3d3674abac3bd1b01a202303d2e748);
#
#
#         var popup_6f71937562d0e8cd70b336cf7b8974a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb0c3a65352b1a6004d667ab6b3037c2 = $(`&lt;div id=&quot;html_cb0c3a65352b1a6004d667ab6b3037c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.ap-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_6f71937562d0e8cd70b336cf7b8974a1.setContent(html_cb0c3a65352b1a6004d667ab6b3037c2);
#
#
#
#         marker_210bf20bd7e7a6ced070f6360414996a.bindPopup(popup_6f71937562d0e8cd70

# %%
# Extract latitude and longitude columns for clustering
coordinates = df_result_nonna[['latitude', 'longitude']]

# Choose the number of clusters (k)
k = 30

# Perform k-means clustering
kmeans = KMeans(n_clusters=k, random_state=42)
df_result_nonna['cluster'] = kmeans.fit_predict(coordinates)

# %%
colors = [
    'red',
    'blue',
    'gray',
    'darkred',
    'lightred',
    'orange',
    'beige',
    'green',
    'darkgreen',
    'lightgreen',
    'darkblue',
    'lightblue',
    'purple',
    'darkpurple',
    'pink',
    'cadetblue',
    'lightgray',
    'black'
]

map_center = [df_result_nonna['latitude'].mean(), df_result_nonna['longitude'].mean()]
map_object = folium.Map(location=map_center, zoom_start=5)

# Add markers for each row in the DataFrame
for index, row in df_result_nonna.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Endpoint'],
        icon=folium.Icon(color=colors[row['cluster'] % len(colors)])
    ).add_to(map_object)

map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2ca9e120fd42d4d1076c80932f67f04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2ca9e120fd42d4d1076c80932f67f04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2ca9e120fd42d4d1076c80932f67f04 = L.map(
#                 &quot;map_d2ca9e120fd42d4d1076c80932f67f04&quot;,
#                 {
#                     center: [25.957980188992945, 30.537745338265257],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c0b8ee981bb7ca73461cb33f5b144e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3c0b8ee981bb7ca73461cb33f5b144e4.addTo(map_d2ca9e120fd42d4d1076c80932f67f04);
#
#
#             var marker_db629b96942e7610707551976b468c99 = L.marker(
#                 [39.043701171875, -77.47419738769531],
#                 {}
#             ).addTo(map_d2ca9e120fd42d4d1076c80932f67f04);
#
#
#             var icon_39b1199142074e9b13318e862670135f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db629b96942e7610707551976b468c99.setIcon(icon_39b1199142074e9b13318e862670135f);
#
#
#         var popup_b8459b9077a3f47e199df822633955af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfe7a28d8d9a3bfffc4a72ef114c4b27 = $(`&lt;div id=&quot;html_cfe7a28d8d9a3bfffc4a72ef114c4b27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_b8459b9077a3f47e199df822633955af.setContent(html_cfe7a28d8d9a3bfffc4a72ef114c4b27);
#
#
#
#         marker_db629b96942e7610707551976b468c99.bindPopup(popup_b8459b9077a3f47e199df822633955af)
#         ;
#
#
#
#
#             var marker_912e07305cac200c770519ee0ebc6988 = L.marker(
#                 [39.99557876586914, -82.99945831298828],
#                 {}
#             ).addTo(map_d2ca9e120fd42d4d1076c80932f67f04);
#
#
#             var icon_c6658454dcdfd4c17089cd9f882594b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_912e07305cac200c770519ee0ebc6988.setIcon(icon_c6658454dcdfd4c17089cd9f882594b6);
#
#
#         var popup_122522eb1c4086ac6d6fe9f00cd23ae2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_69c25fa0e99b756256befc9eb21f86b0 = $(`&lt;div id=&quot;html_69c25fa0e99b756256befc9eb21f86b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-east-2.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_122522eb1c4086ac6d6fe9f00cd23ae2.setContent(html_69c25fa0e99b756256befc9eb21f86b0);
#
#
#
#         marker_912e07305cac200c770519ee0ebc6988.bindPopup(popup_122522eb1c4086ac6d6fe9f00cd23ae2)
#         ;
#
#
#
#
#             var marker_2faf808d720c355cb2fcdc47fae6fe37 = L.marker(
#                 [37.330528259277344, -121.83822631835938],
#                 {}
#             ).addTo(map_d2ca9e120fd42d4d1076c80932f67f04);
#
#
#             var icon_5652df2c548d3294af3d8812037f7026 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2faf808d720c355cb2fcdc47fae6fe37.setIcon(icon_5652df2c548d3294af3d8812037f7026);
#
#
#         var popup_1394db0e4f8eca5cbfde390f145f3b70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7f3c7f77f09fcb3881e4b0c066983d9 = $(`&lt;div id=&quot;html_f7f3c7f77f09fcb3881e4b0c066983d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-west-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_1394db0e4f8eca5cbfde390f145f3b70.setContent(html_f7f3c7f77f09fcb3881e4b0c066983d9);
#
#
#
#         marker_2faf808d720c355cb2fcdc47fae6fe37.bindPopup(popup_1394db0e4f8eca5cbfde390f145f3b70)
#         ;
#
#
#
#
#             var marker_5df22788594e7679801c6f73a1e000fb = L.marker(
#                 [45.83599853515625, -119.6989974975586],
#                 {}
#             ).addTo(map_d2ca9e120fd42d4d1076c80932f67f04);
#
#
#             var icon_60bfc176be1f443499e039267e598b9d = L.Aw

# %%
# Group by cluster and provider, and select unique rows for each group
df_data_centers_by_cluster_provider = df_result_nonna.groupby(['cluster', 'Provider']).first().reset_index()
# Pick at most 2 data centers from each group from above
df_data_centers_by_cluster = df_data_centers_by_cluster_provider.groupby(['cluster']).first().reset_index()

# %%
df_data_centers_by_cluster.shape
# Out:
# (30, 33)

# %%
map_center = [df_data_centers_by_cluster['latitude'].mean(), df_data_centers_by_cluster['longitude'].mean()]
map_object = folium.Map(location=map_center, zoom_start=5)

for index, row in df_data_centers_by_cluster.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Endpoint']
    ).add_to(map_object)

map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9bd2440fb5ea4524748252952f2053e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9bd2440fb5ea4524748252952f2053e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9bd2440fb5ea4524748252952f2053e9 = L.map(
#                 &quot;map_9bd2440fb5ea4524748252952f2053e9&quot;,
#                 {
#                     center: [24.342236789067588, 6.28862624814113],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_575c68c69c00a2c1b34e5d5978e2b454 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_575c68c69c00a2c1b34e5d5978e2b454.addTo(map_9bd2440fb5ea4524748252952f2053e9);
#
#
#             var marker_9cbe3105a778186b7ba09508bf692279 = L.marker(
#                 [45.83599853515625, -119.6989974975586],
#                 {}
#             ).addTo(map_9bd2440fb5ea4524748252952f2053e9);
#
#
#         var popup_868a89536dec5246144b4df2b6e4e4a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efc468ee375df1aad410c2bf7cc7027a = $(`&lt;div id=&quot;html_efc468ee375df1aad410c2bf7cc7027a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-west-2.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_868a89536dec5246144b4df2b6e4e4a2.setContent(html_efc468ee375df1aad410c2bf7cc7027a);
#
#
#
#         marker_9cbe3105a778186b7ba09508bf692279.bindPopup(popup_868a89536dec5246144b4df2b6e4e4a2)
#         ;
#
#
#
#
#             var marker_2d0f348fdd6c98239839019f7f1012bf = L.marker(
#                 [31.22846984863281, 121.47020721435548],
#                 {}
#             ).addTo(map_9bd2440fb5ea4524748252952f2053e9);
#
#
#         var popup_8096d8ce3137d4644afec8bbb3bfd0e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41ddf8b6ced80acdc0d5d124ad0e595e = $(`&lt;div id=&quot;html_41ddf8b6ced80acdc0d5d124ad0e595e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://feitsui-bjs.cn-bj.ufileos.com/ping.html&lt;/div&gt;`)[0];
#                 popup_8096d8ce3137d4644afec8bbb3bfd0e3.setContent(html_41ddf8b6ced80acdc0d5d124ad0e595e);
#
#
#
#         marker_2d0f348fdd6c98239839019f7f1012bf.bindPopup(popup_8096d8ce3137d4644afec8bbb3bfd0e3)
#         ;
#
#
#
#
#             var marker_54e3dc2939f84a671b5f8c7e2ebc602a = L.marker(
#                 [45.46599960327149, 9.186670303344728],
#                 {}
#             ).addTo(map_9bd2440fb5ea4524748252952f2053e9);
#
#
#         var popup_105e61c7687cceb955c976d3906faf5f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2c8c317b6c6699ead5ed2c88623ed3c = $(`&lt;div id=&quot;html_f2c8c317b6c6699ead5ed2c88623ed3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.eu-south-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_105e61c7687cceb955c976d3906faf5f.setContent(html_f2c8c317b6c6699ead5ed2c88623ed3c);
#
#
#
#         marker_54e3dc2939f84a671b5f8c7e2ebc602a.bindPopup(popup_105e61c7687cceb955c976d3906faf5f)
#         ;
#
#
#
#
#             var marker_f56194521fd4d4962aae9b900b041f33 = L.marker(
#                 [-23.54750061035156, -46.6361083984375],
#                 {}
#             ).addTo(map_9bd2440fb5ea4524748252952f2053e9);
#
#
#         var popup_831000278f22708c4d05f348ac6c2990 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46ffc3e9ee145948321a23f47f68f003 = $(`&lt;div id=&quot;html_46ffc3e9ee145948321a23f47f68f003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.sa-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_831000278f22708c4d05f348ac6c2990.setContent(html_46ffc3e9ee145948321a23f47f68f003);
#
#
#
#         marker_f56194521fd4d4962aae9b900b041f33.bindPopup(popup_831000278f22708c4d05f348ac6c2990)
#         ;
#
#
#
#
#             var marker_26fd3921648b3ecbd3db6d9471327812 = L.marker(
#                 [-6.21150016784668, 106.84519958496094],
#                 {}
#             ).addTo(map_9bd2440fb5ea4524748252952f2053e9);
#
#
#         var popup_ebdc3d381e5aacea65a7af7368f0393c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4a3b312e574ba050259eef9fa4ed6c7 = $(`&lt;div id=&quot;html_c4a3b312e574ba050259eef9fa4ed6c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.ap-southeast-3.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_ebdc3d381e5aacea65a7af7368f0393c.setContent(html_c4a3b312e574ba050259eef9fa4ed6c7);
#
#
#
#         marker_26fd3921648b3ecbd3db6d9471327812.bindPopup(popup_ebdc3d381

# %%
df_data_centers_by_cluster.to_csv('cloud_endpoints_final.csv')

# %%
# Here we work with unpacked .json file from the latest probe dataset (09-02-2024)
file_path = '2024/02/20240209.json'

with open(file_path, 'r') as f:
    data = json.load(f)
    df_probes = pd.DataFrame(data['objects'])

# %%
df_probes.head()
# Out:
#    id      address_v4                           address_v6    asn_v4  \
# 0   1   45.138.229.91   2a10:3781:e22:1:220:4aff:fec8:23d7  206238.0
# 1   2            None                                 None    1136.0
# 2   3    77.174.76.85  2a02:a467:f500:1:220:4aff:fec8:2532    1136.0
# 3   4   83.163.50.165   2001:980:57a4:1:220:4aff:fec8:244a    3265.0
# 4   5  83.163.239.181   2001:981:602b:1:220:4aff:fec8:2355    3265.0
#
#      asn_v6        prefix_v4       prefix_v6  is_anchor  is_public  status  \
# 0  206238.0  45.138.228.0/22  2a10:3780::/29      False       True       1
# 1    1136.0    77.160.0.0/13  2a02:a400::/25      False      False       3
# 2    1136.0    77.174.0.0/16  2a02:a400::/25      False       True       1
# 3    3265.0    83.160.0.0/14   2001:980::/32      False       True       3
# 4    3265.0    83.160.0.0/14   2001:980::/30      False       True       3
#
#    status_since  first_connected  total_uptime  \
# 0    1707269398     1.288368e+09     407264862
# 1    1640571508     1.288385e+09     347389948
# 2    1706618589     1.288373e+09     403591652
# 3    1568319241     1.288599e+09     248928764
# 4    1513671789     1.288600e+09     185731720
#
#                                                 tags country_code  latitude  \
# 0  [system-ipv4-stable-1d, system-resolves-aaaa-c...           NL   52.3475
# 1  [system-no-controller-connection, system-ipv6-...           GU   42.6585
# 2  [system-ipv6-stable-1d, system-firewall-proble...           NL   52.3685
# 3  [dsl, home, system-v1, iwantbcp38compliancetes...           NL   52.3895
# 4  [home, nat, system-v1, system-ipv4-capable, sy...           ES   36.8295
#
#    longitude       day                                    probe status_name
# 0     4.9275  20240209  https://atlas.ripe.net/api/v2/probes/1/   Connected
# 1    21.1575  20240209  https://atlas.ripe.net/api/v2/probes/2/   Abandoned
# 2     4.9375  20240209  https://atlas.ripe.net/api/v2/probes/3/   Connected
# 3     4.6375  20240209  https://atlas.ripe.net/api/v2/probes/4/   Abandoned
# 4    -2.4625  20240209  https://atlas.ripe.net/api/v2/probes/5/   Abandoned

# %%
df_probes_filtered = df_probes
df_probes_filtered['tags'] = df_probes['tags'].apply(set)
# Only pick those probes with 1-day stable IP to improve reliability of our measurement
df_probes_filtered = df_probes_filtered[df_probes_filtered['tags'].apply(lambda tags: 'system-ipv4-stable-1d' in tags)]
# Only pick probes with status equal 1
df_probes_filtered = df_probes_filtered[df_probes_filtered['status'] == 1]

# %%
df_probes_filtered.shape
# Out:
# (7095, 20)

# %%
# Total number of probes we want for our measurement
total_probes = 150

# Share of population by continent
continent_population_share = {
    'NA': 7.5,
    'SA': 5.5,
    'AS': 59.4,
    'OC': 0.6,
    'AF': 17.6,
    'EU': 9.4
}


# Pick samples from a probe dataframe respecting the population
# share by continent
def pick_samples_by_continent(df, population_distribution):
    samples = []

    for continent, share in population_distribution.items():
        # Check if the continent has entries in the DataFrame
        if df[df['continent'] == continent].empty:
            continue

        # Calculate the number of samples based on the share
        num_samples = int(np.ceil(len(df) * share / 100))

        # Select samples for the current continent
        samples_continent = df[df['continent'] == continent].sample(n=num_samples, replace=True)

        # Append the selected samples to the result list
        samples.append(samples_continent)

    # Concatenate the list of DataFrames into a single one
    result_df = pd.concat(samples, ignore_index=True)

    return result_df


# Convert country code to continent
def country_to_continent(country_code):
    try:
        return pc.country_alpha2_to_continent_code(country_code)
    except KeyError:
        return None

# %%
df_probes_filtered['continent'] = df_probes_filtered['country_code'].apply(country_to_continent)

# %%
df_probes_filtered.head()
# Out:
#     id     address_v4                              address_v6    asn_v4  \
# 0    1  45.138.229.91      2a10:3781:e22:1:220:4aff:fec8:23d7  206238.0
# 7    8   83.81.83.145  2001:1c05:2011:fa00:220:4aff:fec8:2464   33915.0
# 13  14  79.55.209.251                                    None    3269.0
# 29  30           None                                    None   20115.0
# 31  32   76.82.152.84  2603:8001:5000:2aa0:220:4aff:fec8:25ed   20001.0
#
#       asn_v6        prefix_v4       prefix_v6  is_anchor  is_public  status  \
# 0   206238.0  45.138.228.0/22  2a10:3780::/29      False       True       1
# 7    33915.0     83.80.0.0/14  2001:1c00::/24      False       True       1
# 13       NaN     79.55.0.0/16            None      False       True       1
# 29       NaN   75.142.96.0/19            None      False      False       1
# 31   20001.0     76.80.0.0/14  2603:8000::/28      False       True       1
#
#     ...  first_connected  total_uptime  \
# 0   ...     1.288368e+09     407264862
# 7   ...     1.288619e+09     405485386
# 13  ...     1.289551e+09     352983358
# 29  ...     1.290200e+09     170845189
# 31  ...     1.289868e+09     406671689
#
#                                                  tags country_code latitude  \
# 0   {dsl, system-resolves-a-correctly, system-reso...           NL  52.3475
# 7   {sourceaddressspoofok, system-ipv4-capable, na...           NL  51.1915
# 13  {system-resolves-a-correctly, system-resolves-...           IT  41.8995
# 29  {system-resolves-a-correctly, system-resolves-...           US  33.8175
# 31  {system-ipv4-capable, native-ipv6, system-ipv6...           US  32.8885
#
#     longitude       day                                     probe status_name  \
# 0      4.9275  20240209   https://atlas.ripe.net/api/v2/probes/1/   Connected
# 7      5.9975  20240209   https://atlas.ripe.net/api/v2/probes/8/   Connected
# 13    12.4375  20240209  https://atlas.ripe.net/api/v2/probes/14/   Connected
# 29  -118.0615  20240209  https://atlas.ripe.net/api/v2/probes/30/   Connected
# 31  -117.1815  20240209  https://atlas.ripe.net/api/v2/probes/32/   Connected
#
#    continent
# 0         EU
# 7         EU
# 13        EU
# 29        NA
# 31        NA
#
# [5 rows x 21 columns]

# %%
# Define filters for different probe classes
filters = {
    "radio (wi-fi)": lambda row: 'home' in row['tags'] and any(
        x in row['tags'] for x in {"wi-fi", "wifi", "wlan", "wireless", "wireless-isp", "wireless-link"}),
    "radio (mobile)": lambda row: any(x in row['tags'] for x in {"lte", "5g", "4g", "3g", "cellular"}),
    "satellite": lambda row: row["asn_v4"] == 14593 or row["asn_v6"] == 14593,
    "ethernet": lambda row: 'home' in row['tags'] and not any(x in row['tags'] for x in {"wi-fi", "wifi", "wlan"}) and  any(
        x in row['tags'] for x in {"dsl", "adsl", "fibre", "fiber", "cable", "ftth"})
}

# %%
filtered_probe_frames = {}

for filter_name, filter_func in filters.items():
    df_filtered_temp = df_probes_filtered[df_probes_filtered.apply(filter_func, axis=1)]
    selected_samples = pick_samples_by_continent(df_filtered_temp, continent_population_share)

    if filter_name == "satellite":
        filtered_probe_frames[filter_name] = df_filtered_temp
    elif filter_name == "ethernet":
        filtered_probe_frames[filter_name] = selected_samples.sample(n=520, replace=True)
    else:
        filtered_probe_frames[filter_name] = selected_samples

    filtered_probe_frames[filter_name] = filtered_probe_frames[filter_name].sample(frac=1.0, replace=True)

# %%
# We verify we have ~170 unique probes after final sampling
c = 0
for filter_name, probe_df in filtered_probe_frames.items():
    c += probe_df.shape[0]
    print(filter_name, ": ", probe_df.shape[0])
print("All probes:", c)

all_filtered_probes = pd.concat(filtered_probe_frames.values(), ignore_index=True)

print("Unique probes:", len(set(all_filtered_probes['id'].tolist())))
# Out:
# radio (wi-fi) :  51
# radio (mobile) :  47
# satellite :  12
# ethernet :  520
# All probes: 630
# Unique probes: 174

# %%
all_filtered_probes.to_csv('all_filtered_probes.csv')

# %%
df_data_centers_by_cluster.head()
# Out:
#    cluster Provider  Unnamed: 0  \
# 0        0      AWS           4
# 1        1   UCloud         103
# 2        2      AWS          16
# 3        3      AWS          26
# 4        4      AWS          13
#
#                                           Endpoint      State       City  \
# 0         https://ec2.us-west-2.amazonaws.com/ping     Oregon   Portland
# 1  https://feitsui-bjs.cn-bj.ufileos.com/ping.html      cn-bj    Beijing
# 2        https://ec2.eu-south-1.amazonaws.com/ping      Milan      Milan
# 3         https://ec2.sa-east-1.amazonaws.com/ping  São Paulo  São Paulo
# 4    https://ec2.ap-southeast-3.amazonaws.com/ping    Jakarta    Jakarta
#
#          Country              IP  \
# 0  United States    52.94.214.88
# 1          China   117.50.123.29
# 2          Italy   52.119.132.74
# 3         Brazil  177.72.245.165
# 4      Indonesia   99.78.244.123
#
#                                         geo_response              ip  ...  \
# 0  {'ip': '52.94.214.88', 'type': 'ipv4', 'contin...    52.94.214.88  ...
# 1  {'ip': '117.50.123.29', 'type': 'ipv4', 'conti...   117.50.123.29  ...
# 2  {'ip': '52.119.132.74', 'type': 'ipv4', 'conti...   52.119.132.74  ...
# 3  {'ip': '177.72.245.165', 'type': 'ipv4', 'cont...  177.72.245.165  ...
# 4  {'ip': '99.78.244.123', 'type': 'ipv4', 'conti...   99.78.244.123  ...
#
#                                   location.languages  \
# 0  [{'code': 'en', 'name': 'English', 'native': '...
# 1  [{'code': 'zh', 'name': 'Chinese', 'native': '...
# 2  [{'code': 'it', 'name': 'Italian', 'native': '...
# 3  [{'code': 'pt', 'name': 'Portuguese', 'native'...
# 4  [{'code': 'id', 'name': 'Indonesian', 'native'...
#
#                      location.country_flag location.country_flag_emoji  \
# 0  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 1  https://assets.ipstack.com/flags/cn.svg                          🇨🇳
# 2  https://assets.ipstack.com/flags/it.svg                          🇮🇹
# 3  https://assets.ipstack.com/flags/br.svg                          🇧🇷
# 4  https://assets.ipstack.com/flags/id.svg                          🇮🇩
#
#   location.country_flag_emoji_unicode location.calling_code location.is_eu  \
# 0                     U+1F1FA U+1F1F8                     1          False
# 1                     U+1F1E8 U+1F1F3                    86          False
# 2                     U+1F1EE U+1F1F9                    39           True
# 3                     U+1F1E7 U+1F1F7                    55          False
# 4                     U+1F1EE U+1F1E9                    62          False
#
#   success error.code error.type  error.info
# 0     NaN        NaN        NaN         NaN
# 1     NaN        NaN        NaN         NaN
# 2     NaN        NaN        NaN         NaN
# 3     NaN        NaN        NaN         NaN
# 4     NaN        NaN        NaN         NaN
#
# [5 rows x 33 columns]

# %%
def map_function_on_keys_and_values(obj, keys_to_map, func):
    if isinstance(obj, dict):
        for key, value in obj.items():
            if key in keys_to_map:
                obj[key] = func(value)
            else:
                obj[key] = map_function_on_keys_and_values(value, keys_to_map, func)
        return obj
    elif isinstance(obj, list):
        return [map_function_on_keys_and_values(item, keys_to_map, func) for item in obj]
    else:
        return obj


def add_measurement_interval(definitions):
    for definition in definitions:
        definition["interval"] = 14400
    return definitions

# %%
def create_traceroute_measurements(probe_df, data_center_df):
    ATLAS_API_KEY = os.getenv('ATLAS_API_KEY')
    ATLAS_API_URL = "https://atlas.ripe.net/api/v2/measurements"
    HEADERS = {"Content-Type": "application/json", "Accept": "application/json"}
    CALL_PARAMS = {"key": ATLAS_API_KEY}

    probe_ids = list(set(probe_df["id"].tolist()))

    measurement_source = AtlasSource(
        type="probes",
        value=",".join(map(str, probe_ids)),
        requested=len(probe_ids)
    )

    responses = []

    start_time_utc = datetime.utcnow() + timedelta(minutes=5)

    for index, row in data_center_df.iterrows():
        traceroute = Traceroute(af=4, target=row["IP"], protocol="ICMP",
                    description=f"{row['Provider']} data center endpoint {row['Endpoint']} in {row['City']}, {row['State']}, {row['Country']}")

        atlas_request = AtlasCreateRequest(
            start_time=start_time_utc,
            key=ATLAS_API_KEY,
            measurements=[traceroute],
            sources=[measurement_source],
            is_oneoff=True
        )

        atlas_request._construct_post_data()

        response = requests.post(ATLAS_API_URL, headers=HEADERS, params=CALL_PARAMS, json=atlas_request.post_data)
        responses.append(response)
        print(response.status_code, ": ", response.text)

    return responses

# %%
def create_ping_measurements(probe_df, data_center_df):
    ATLAS_API_KEY = os.getenv('ATLAS_API_KEY')
    ATLAS_API_URL = "https://atlas.ripe.net/api/v2/measurements"
    HEADERS = {"Content-Type": "application/json", "Accept": "application/json"}
    CALL_PARAMS = {"key": ATLAS_API_KEY}

    probe_ids = probe_df["id"].tolist()

    measurement_source = AtlasSource(
        type="probes",
        value=",".join(map(str, probe_ids)),
        requested=len(probe_ids)
    )

    responses = []

    start_time_utc = datetime.utcnow() + timedelta(minutes=5)
    end_time_utc = start_time_utc + timedelta(weeks=1)

    for index, row in data_center_df.iterrows():
        ping = Ping(af=4, target=row["IP"],
                    description=f"{row['Provider']} data center endpoint {row['Endpoint']} in {row['City']}, {row['State']}, {row['Country']}")

        atlas_request = AtlasCreateRequest(
            start_time=start_time_utc,
            stop_time=end_time_utc,
            key=ATLAS_API_KEY,
            measurements=[ping],
            sources=[measurement_source],
            is_oneoff=False
        )

        atlas_request._construct_post_data()
        atlas_request.post_data = map_function_on_keys_and_values(atlas_request.post_data, 'definitions',
                                                                  add_measurement_interval)
        
        response = requests.post(ATLAS_API_URL, headers=HEADERS, params=CALL_PARAMS, json=atlas_request.post_data)
        responses.append(response)
        print(response.status_code, ": ", response.text)

    return responses

# %%
#To create ping measurements
#ping_responses = create_ping_measurements(all_filtered_probes, df_data_centers_by_cluster)
# Out:
# 201 :  {"measurements":[67859951]}
# 201 :  {"measurements":[67859952]}
# 201 :  {"measurements":[67859953]}
# 201 :  {"measurements":[67859954]}
# 201 :  {"measurements":[67859956]}
# 201 :  {"measurements":[67859957]}
# 201 :  {"measurements":[67859958]}
# 201 :  {"measurements":[67859959]}
# 201 :  {"measurements":[67859960]}
# 201 :  {"measurements":[67859961]}
# 201 :  {"measurements":[67859962]}
# 201 :  {"measurements":[67859963]}
# 201 :  {"measurements":[67859964]}
# 201 :  {"measurements":[67859965]}
# 201 :  {"measurements":[67859966]}
# 201 :  {"measurements":[67859967]}
# 201 :  {"measurements":[67859968]}
# 201 :  {"measurements":[67859969]}
# 201 :  {"measurements":[67859970]}
# 201 :  {"measurements":[67859971]}
# 201 :  {"measurements":[67859972]}
# 201 :  {"measurements":[67859973]}
# 201 :  {"measurements":[67859974]}
# 201 :  {"measurements":[67859975]}
# 201 :  {"measurements":[67859976]}
# 201 :  {"measurements":[67859977]}
# 201 :  {"measurements":[67859978]}
# 201 :  {"measurements":[67859979]}
# 201 :  {"measurements":[67859980]}
# 201 :  {"measurements":[67859981]}

# %%
len(ping_responses)
# Out:
# 30

# %%
#To create traceroute measurements
#traceroute_measurements = create_traceroute_measurements(all_filtered_probes, df_data_centers_by_cluster)
# Out:
# 201 :  {"measurements":[67859982]}
# 201 :  {"measurements":[67859983]}
# 201 :  {"measurements":[67859984]}
# 201 :  {"measurements":[67859985]}
# 201 :  {"measurements":[67859986]}
# 201 :  {"measurements":[67859987]}
# 201 :  {"measurements":[67859988]}
# 201 :  {"measurements":[67859989]}
# 201 :  {"measurements":[67859990]}
# 201 :  {"measurements":[67859991]}
# 201 :  {"measurements":[67859993]}
# 201 :  {"measurements":[67859994]}
# 201 :  {"measurements":[67859995]}
# 201 :  {"measurements":[67859996]}
# 201 :  {"measurements":[67859997]}
# 201 :  {"measurements":[67859998]}
# 201 :  {"measurements":[67859999]}
# 201 :  {"measurements":[67860001]}
# 201 :  {"measurements":[67860002]}
# 201 :  {"measurements":[67860003]}
# 201 :  {"measurements":[67860004]}
# 201 :  {"measurements":[67860005]}
# 201 :  {"measurements":[67860006]}
# 201 :  {"measurements":[67860007]}
# 201 :  {"measurements":[67860008]}
# 201 :  {"measurements":[67860009]}
# 201 :  {"measurements":[67860010]}
# 201 :  {"measurements":[67860011]}
# 201 :  {"measurements":[67860013]}
# 201 :  {"measurements":[67860014]}

# %%
ping_measurements_ids = [67652477,
                         67652478,
                         67652479,
                         67652480,
                         67652481,
                         67652482,
                         67652483,
                         67652484,
                         67652485,
                         67652487,
                         67652488,
                         67652489,
                         67652490,
                         67652491,
                         67652492,
                         67652493,
                         67652494,
                         67652495,
                         67652496,
                         67652498,
                         67652499,
                         67652500,
                         67652501,
                         67652502,
                         67652503,
                         67652504,
                         67652505,
                         67652506,
                         67652507,
                         67652508]

# %%
traceroute_measurement_ids = [67663401,
                              67663402,
                              67663404,
                              67663406,
                              67663408,
                              67663410,
                              67663411,
                              67663413,
                              67663414,
                              67663416,
                              67663419,
                              67663420,
                              67663422,
                              67663424,
                              67663426,
                              67663427,
                              67663429,
                              67663431,
                              67663433,
                              67663434,
                              67663436,
                              67663439,
                              67663440,
                              67663443,
                              67663445,
                              67663447,
                              67663448,
                              67663450,
                              67663452,
                              67663454]

# %%
def flatten_list(nested_list):
    return [item for sublist in nested_list for item in sublist]

def fetch_measurement_results(ids):
    ATLAS_API_KEY = os.getenv('ATLAS_API_KEY')

    results = []

    for id in ids:
        request_params = {
            "msm_id": id,
        }

        atlas_request = AtlasResultsRequest(is_authenticated=True, key=ATLAS_API_KEY, **request_params)

        for result in atlas_request.create():
            results.append(result)

    results = [x for x in results if isinstance(x, list)]
    results = flatten_list(results)
    
    return pd.DataFrame(results)

# %%
ping_results = fetch_measurement_results(ping_measurements_ids)

# %%
ping_results.head()
# Out:
#       fw   mver  lts      dst_name  af      dst_addr         src_addr proto  \
# 0   5080  2.6.2    4  52.94.214.88   4  52.94.214.88  192.168.100.100  ICMP
# 1   5010  2.2.0   24  52.94.214.88   4  52.94.214.88    192.168.99.18  ICMP
# 2   5080  2.6.2    2  52.94.214.88   4  52.94.214.88     192.168.96.2  ICMP
# 3   5040  2.4.1    6  52.94.214.88   4  52.94.214.88     172.16.2.128  ICMP
# 4   5080  2.6.2   77  52.94.214.88   4  52.94.214.88       172.17.0.2  ICMP
# ..   ...    ...  ...           ...  ..           ...              ...   ...
# 95  5080  2.6.2   32  52.94.214.88   4  52.94.214.88     192.168.1.21  ICMP
# 96  5080  2.6.2   44  52.94.214.88   4  52.94.214.88     192.168.5.22  ICMP
# 97  5080  2.6.2   60  52.94.214.88   4  52.94.214.88    192.168.0.162  ICMP
# 98  5080  2.6.2   45  52.94.214.88   4  52.94.214.88    192.168.3.106  ICMP
# 99  5080  2.6.2   74  52.94.214.88   4  52.94.214.88   172.16.254.197  ICMP
#
#       ttl  size  ...         avg    msm_id   prb_id   timestamp  msm_name  \
# 0   239.0    64  ...  265.449459  67652477  1000245  1707656935      Ping
# 1   229.0    64  ...  212.986177  67652477  1000465  1707656932      Ping
# 2   239.0    64  ...  239.769113  67652477  1002179  1707656939      Ping
# 3   241.0    64  ...  320.277881  67652477  1003912  1707656937      Ping
# 4   238.0    64  ...  130.307804  67652477  1005043  1707656933      Ping
# ..    ...   ...  ...         ...       ...      ...         ...       ...
# 95  231.0    64  ...  195.636243  67652477    13308  1707657139      Ping
# 96  234.0    64  ...  314.521598  67652477    14691  1707657128      Ping
# 97  237.0    64  ...  176.285159  67652477    15794  1707657134      Ping
# 98  236.0    64  ...  310.654188  67652477    21120  1707657138      Ping
# 99  242.0    64  ...   50.829392  67652477    22802  1707657152      Ping
#
#                from  type  group_id   step  stored_timestamp
# 0    94.201.115.148  ping  67652477  14400        1707656979
# 1     85.64.211.119  ping  67652477  14400        1707656973
# 2      2.134.22.170  ping  67652477  14400        1707656998
# 3       2.51.60.117  ping  67652477  14400        1707657062
# 4      121.138.25.4  ping  67652477  14400        1707657054
# ..              ...   ...       ...    ...               ...
# 95   31.136.193.196  ping  67652477  14400        1707657270
# 96    169.1.145.175  ping  67652477  14400        1707657145
# 97     5.132.87.115  ping  67652477  14400        1707657263
# 98  197.234.182.101  ping  67652477  14400        1707657270
# 99  216.147.124.107  ping  67652477  14400        1707657266
#
# [100 rows x 26 columns]

# %%
ping_results = ping_results[ping_results['result'].apply(lambda x: len([y for y in x if 'rtt' in y])) > 0]
ping_results['average_rtt'] = ping_results['result'].apply(lambda x : mean([y['rtt'] for y in x if 'rtt' in y]))

# %%
ping_results.head()
# Out:
#      fw   mver  lts      dst_name  af      dst_addr         src_addr proto  \
# 0  5080  2.6.2    4  52.94.214.88   4  52.94.214.88  192.168.100.100  ICMP
# 1  5010  2.2.0   24  52.94.214.88   4  52.94.214.88    192.168.99.18  ICMP
# 2  5080  2.6.2    2  52.94.214.88   4  52.94.214.88     192.168.96.2  ICMP
# 3  5040  2.4.1    6  52.94.214.88   4  52.94.214.88     172.16.2.128  ICMP
# 4  5080  2.6.2   77  52.94.214.88   4  52.94.214.88       172.17.0.2  ICMP
#
#      ttl  size  ...    msm_id   prb_id   timestamp  msm_name            from  \
# 0  239.0    64  ...  67652477  1000245  1707656935      Ping  94.201.115.148
# 1  229.0    64  ...  67652477  1000465  1707656932      Ping   85.64.211.119
# 2  239.0    64  ...  67652477  1002179  1707656939      Ping    2.134.22.170
# 3  241.0    64  ...  67652477  1003912  1707656937      Ping     2.51.60.117
# 4  238.0    64  ...  67652477  1005043  1707656933      Ping    121.138.25.4
#
#    type  group_id   step  stored_timestamp  average_rtt
# 0  ping  67652477  14400        1707656979   265.449459
# 1  ping  67652477  14400        1707656973   212.986177
# 2  ping  67652477  14400        1707656998   239.769113
# 3  ping  67652477  14400        1707657062   320.277881
# 4  ping  67652477  14400        1707657054   130.307804
#
# [5 rows x 27 columns]

# %%
# Load probes dataframe
all_filtered_probes_df = pd.read_csv('all_filtered_probes.csv')

# %%
all_filtered_probes_df.head()

# Join the ping results with probes
ping_results_joined_df = pd.merge(ping_results, all_filtered_probes_df, left_on='prb_id', right_on='id')

# %%
def associate_probe_type(row):
    for filter_name, filter_func in filters.items():
        if filter_func(row):
            return filter_name

    return "unknown"

# %%
ping_results_joined_df['probe_type'] = ping_results_joined_df.apply(associate_probe_type, axis=1)

# %%
ping_results_joined_df.head()
# Out:
#      fw   mver  lts      dst_name  af      dst_addr         src_addr proto  \
# 0  5080  2.6.2    4  52.94.214.88   4  52.94.214.88  192.168.100.100  ICMP
# 1  5080  2.6.2    4  52.94.214.88   4  52.94.214.88  192.168.100.100  ICMP
# 2  5080  2.6.2    4  52.94.214.88   4  52.94.214.88  192.168.100.100  ICMP
# 3  5080  2.6.2    4  52.94.214.88   4  52.94.214.88  192.168.100.100  ICMP
# 4  5080  2.6.2    4  52.94.214.88   4  52.94.214.88  192.168.100.100  ICMP
#
#      ttl  size  ... total_uptime  \
# 0  239.0    64  ...    101337867
# 1  239.0    64  ...    101337867
# 2  239.0    64  ...    101337867
# 3  239.0    64  ...    101337867
# 4  239.0    64  ...    101337867
#
#                                                 tags  country_code  latitude  \
# 0  {'fibre', 'system-resolves-a-correctly', 'syst...            AE   25.0895
# 1  {'fibre', 'system-resolves-a-correctly', 'syst...            AE   25.0895
# 2  {'fibre', 'system-resolves-a-correctly', 'syst...            AE   25.0895
# 3  {'fibre', 'system-resolves-a-correctly', 'syst...            AE   25.0895
# 4  {'fibre', 'system-resolves-a-correctly', 'syst...            AE   25.0895
#
#    longitude       day                                          probe  \
# 0    55.2595  20240209  https://atlas.ripe.net/api/v2/probes/1000245/
# 1    55.2595  20240209  https://atlas.ripe.net/api/v2/probes/1000245/
# 2    55.2595  20240209  https://atlas.ripe.net/api/v2/probes/1000245/
# 3    55.2595  20240209  https://atlas.ripe.net/api/v2/probes/1000245/
# 4    55.2595  20240209  https://atlas.ripe.net/api/v2/probes/1000245/
#
#    status_name  continent  probe_type
# 0    Connected         AS    ethernet
# 1    Connected         AS    ethernet
# 2    Connected         AS    ethernet
# 3    Connected         AS    ethernet
# 4    Connected         AS    ethernet
#
# [5 rows x 50 columns]

# %%
ping_results_joined_df.to_csv('ping_results.csv')

# %%
traceroute_results = fetch_measurement_results(traceroute_measurement_ids)

# %%
# Join the traceroute results with probes
traceroute_results_df = pd.merge(traceroute_results, all_filtered_probes_df, left_on='prb_id', right_on='id')

# %%
traceroute_results_df['probe_type'] = traceroute_results_df.apply(associate_probe_type, axis=1)

# %%
traceroute_results_df.head()
# Out:
#      fw   mver  lts     endtime      dst_name      dst_addr       src_addr  \
# 0  5080  2.6.2   76  1707692065  52.94.214.88  52.94.214.88  192.168.2.100
# 1  5080  2.6.2   76  1707692065  52.94.214.88  52.94.214.88  192.168.2.100
# 2  5080  2.6.2   76  1707692065  52.94.214.88  52.94.214.88  192.168.2.100
# 3  5080  2.6.2   76  1707692065  52.94.214.88  52.94.214.88  192.168.2.100
# 4  5080  2.6.2   76  1707692065  52.94.214.88  52.94.214.88  192.168.2.100
#
#   proto  af  size  ...  total_uptime  \
# 0  ICMP   4    48  ...     132694981
# 1  ICMP   4    48  ...     132694981
# 2  ICMP   4    48  ...     132694981
# 3  ICMP   4    48  ...     132694981
# 4  ICMP   4    48  ...     132694981
#
#                                                 tags  country_code  latitude  \
# 0  {'system-ipv4-capable', 'native-ipv6', 'system...            TR   39.9885
# 1  {'system-ipv4-capable', 'native-ipv6', 'system...            TR   39.9885
# 2  {'system-ipv4-capable', 'native-ipv6', 'system...            TR   39.9885
# 3  {'system-ipv4-capable', 'native-ipv6', 'system...            TR   39.9885
# 4  {'system-ipv4-capable', 'native-ipv6', 'system...            TR   39.9885
#
#    longitude       day                                          probe  \
# 0    32.8185  20240209  https://atlas.ripe.net/api/v2/probes/1000023/
# 1    32.8185  20240209  https://atlas.ripe.net/api/v2/probes/1000023/
# 2    32.8185  20240209  https://atlas.ripe.net/api/v2/probes/1000023/
# 3    32.8185  20240209  https://atlas.ripe.net/api/v2/probes/1000023/
# 4    32.8185  20240209  https://atlas.ripe.net/api/v2/probes/1000023/
#
#   status_name continent  probe_type
# 0   Connected        AS    ethernet
# 1   Connected        AS    ethernet
# 2   Connected        AS    ethernet
# 3   Connected        AS    ethernet
# 4   Connected        AS    ethernet
#
# [5 rows x 44 columns]

# %%
traceroute_results_df.to_csv('traceroute_results.csv')

# %%
ping_results_df = ping_results_joined_df

# %%
# North America (US + CA) is continent=null for some reason
ping_results_df[ping_results_df['continent'].isnull()]['country_code'].unique()
# Out:
# array(['US', 'CA'], dtype=object)
