# %%
import os
import json
import folium
import requests
import pycountry
import pandas as pd
import pycountry_convert as pc
from pandas import json_normalize
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('cloudregions.csv', names=["Endpoint", "Provider", "State", "City", "Country", "IP"])

# %%
df.head()
# Out:
#                                    Endpoint Provider          State  \
# 0  https://ec2.us-east-1.amazonaws.com/ping      AWS    N. Virginia
# 1  https://ec2.us-east-2.amazonaws.com/ping      AWS           Ohio
# 2  https://ec2.us-west-1.amazonaws.com/ping      AWS  N. California
# 3                                       NaN      AWS  N. California
# 4  https://ec2.us-west-2.amazonaws.com/ping      AWS         Oregon
#
#             City        Country              IP
# 0        Ashburn  United States   52.46.142.79;
# 1       Columbus  United States  99.78.176.246;
# 2  San Francisco  United States  176.32.118.30;
# 3  San Francisco  United States              0;
# 4       Portland  United States   52.94.214.88;

# %%
# Clean up the IP address
df["IP"] = df["IP"].str[:-1]

# %%
df.head()
# Out:
#                                    Endpoint Provider          State  \
# 0  https://ec2.us-east-1.amazonaws.com/ping      AWS    N. Virginia
# 1  https://ec2.us-east-2.amazonaws.com/ping      AWS           Ohio
# 2  https://ec2.us-west-1.amazonaws.com/ping      AWS  N. California
# 3                                       NaN      AWS  N. California
# 4  https://ec2.us-west-2.amazonaws.com/ping      AWS         Oregon
#
#             City        Country             IP
# 0        Ashburn  United States   52.46.142.79
# 1       Columbus  United States  99.78.176.246
# 2  San Francisco  United States  176.32.118.30
# 3  San Francisco  United States              0
# 4       Portland  United States   52.94.214.88

# %%
# Define a function to make HTTP requests
def make_request(row):
    if row['IP'] == "0":
        return json.dumps("{}")
    
    url = f"http://api.ipstack.com/{row['IP']}?access_key=af9d6f3b9d4984149040eaa8098938c5"
    
    try:
        response = requests.get(url)
        print(f"URL: {url}, Status Code: {response.status_code}")
        return response.json()
    except Exception as e:
        print(f"Error for URL {url}: {e}")
        return None

# %%
# Retrieve geolocation data for each IP address (only first 100 will be successful due to API limits)
df['geo_response'] = df.apply(make_request, axis=1)
# Out:
# URL: http://api.ipstack.com/52.46.142.79?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/99.78.176.246?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/176.32.118.30?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.94.214.88?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/13.248.32.123?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.95.88.14?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/13.248.4.70?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.95.193.80?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/15.221.8.221?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/99.83.82.12?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/99.78.244.123?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/99.77.58.81?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.94.108.110?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.119.132.74?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.94.141.11?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.95.122.167?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.94.56.52?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.46.72.50?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/52.46.192.128?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/99.82.128.102?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/99.78.128.100?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/177.72.245.165?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/149.129.143.68?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/47.254.218.26?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/47.254.114.114?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/149.129.200.34?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/161.117.155.93?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/8.212.139.140?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/47.74.79.155?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/8.213.160.102?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/47.91.99.18?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/149.129.12.59?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/47.254.186.91?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/47.253.30.167?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/47.245.49.2?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/8.208.40.164?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/47.75.19.16?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.194.105?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.219.200?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/104.156.230.107?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/104.156.244.232?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.193.166?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/208.72.154.76?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/107.191.51.12?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.149.182?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.224.175?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/149.248.50.81?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/216.238.66.16?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/216.238.98.118?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.210.117?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/208.76.222.30?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.209.127?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.196.101?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.198.102?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/70.34.242.24?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/70.34.194.86?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.201.151?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/141.164.34.61?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/45.32.100.168?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/108.61.212.117?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/67.219.110.24?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/50.116.57.237?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/192.155.94.157?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/50.116.25.154?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/50.116.14.9?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/172.105.30.21?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/139.162.130.8?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/176.58.107.39?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/139.162.23.4?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/172.105.174.7?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/139.162.65.37?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/172.105.33.31?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/43.132.105.108?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/43.128.193.10?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/43.129.45.240?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/101.32.231.20?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/119.28.147.117?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/43.152.64.193?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/43.128.240.52?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/49.51.77.119?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/170.106.97.195?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/49.51.54.104?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/43.157.144.10?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/162.62.150.176?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/123.58.223.81?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/152.32.231.7?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/23.248.185.157?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/172.96.124.45?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/128.14.225.21?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/152.32.152.148?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/45.40.56.163?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/165.154.85.11?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/104.218.162.88?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/23.248.184.33?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/118.193.76.37?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/128.14.235.16?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/152.32.160.34?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/117.50.123.29?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/106.75.183.117?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/113.31.160.176?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/78.46.170.2?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/95.217.255.81?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/5.161.7.195?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/5.78.7.195?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.44.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.128.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.100.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.172.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.96.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.72.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.124.2?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.176.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.92.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.84.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.200.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.112.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.28.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.152.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.156.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.104.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.144.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.80.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.148.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.88.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.120.2?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.108.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.140.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.132.2?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.136.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.8.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.116.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.160.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.164.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.168.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.64.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.76.3?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.180.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.184.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200
# URL: http://api.ipstack.com/134.70.192.1?access_key=af9d6f3b9d4984149040eaa8098938c5, Status Code: 200

# %%
# Explode the JSON response into separate columns
df_normalized = json_normalize(df['geo_response'])

# %%
df_normalized.head()
# Out:
#               ip  type continent_code continent_name country_code  \
# 0   52.46.142.79  ipv4             NA  North America           US
# 1  99.78.176.246  ipv4             NA  North America           US
# 2  176.32.118.30  ipv4             NA  North America           US
# 3            NaN   NaN            NaN            NaN          NaN
# 4   52.94.214.88  ipv4             NA  North America           US
#
#     country_name region_code region_name      city    zip  ...  \
# 0  United States          VA    Virginia   Ashburn  20147  ...
# 1  United States          OH        Ohio  Columbus  43201  ...
# 2  United States          CA  California  San Jose  95122  ...
# 3            NaN         NaN         NaN       NaN    NaN  ...
# 4  United States          OR      Oregon  Boardman  97818  ...
#
#                                   location.languages  \
# 0  [{'code': 'en', 'name': 'English', 'native': '...
# 1  [{'code': 'en', 'name': 'English', 'native': '...
# 2  [{'code': 'en', 'name': 'English', 'native': '...
# 3                                                NaN
# 4  [{'code': 'en', 'name': 'English', 'native': '...
#
#                      location.country_flag  location.country_flag_emoji  \
# 0  https://assets.ipstack.com/flags/us.svg                           🇺🇸
# 1  https://assets.ipstack.com/flags/us.svg                           🇺🇸
# 2  https://assets.ipstack.com/flags/us.svg                           🇺🇸
# 3                                      NaN                          NaN
# 4  https://assets.ipstack.com/flags/us.svg                           🇺🇸
#
#   location.country_flag_emoji_unicode location.calling_code location.is_eu  \
# 0                     U+1F1FA U+1F1F8                     1          False
# 1                     U+1F1FA U+1F1F8                     1          False
# 2                     U+1F1FA U+1F1F8                     1          False
# 3                                 NaN                   NaN            NaN
# 4                     U+1F1FA U+1F1F8                     1          False
#
#   success error.code error.type error.info
# 0     NaN        NaN        NaN        NaN
# 1     NaN        NaN        NaN        NaN
# 2     NaN        NaN        NaN        NaN
# 3     NaN        NaN        NaN        NaN
# 4     NaN        NaN        NaN        NaN
#
# [5 rows x 24 columns]

# %%
df_result = pd.concat([df, df_normalized], axis=1)

# %%
df_result.head()
# Out:
#                                    Endpoint Provider          State  \
# 0  https://ec2.us-east-1.amazonaws.com/ping      AWS    N. Virginia
# 1  https://ec2.us-east-2.amazonaws.com/ping      AWS           Ohio
# 2  https://ec2.us-west-1.amazonaws.com/ping      AWS  N. California
# 3                                       NaN      AWS  N. California
# 4  https://ec2.us-west-2.amazonaws.com/ping      AWS         Oregon
#
#             City        Country             IP  \
# 0        Ashburn  United States   52.46.142.79
# 1       Columbus  United States  99.78.176.246
# 2  San Francisco  United States  176.32.118.30
# 3  San Francisco  United States              0
# 4       Portland  United States   52.94.214.88
#
#                                         geo_response             ip  type  \
# 0  {'ip': '52.46.142.79', 'type': 'ipv4', 'contin...   52.46.142.79  ipv4
# 1  {'ip': '99.78.176.246', 'type': 'ipv4', 'conti...  99.78.176.246  ipv4
# 2  {'ip': '176.32.118.30', 'type': 'ipv4', 'conti...  176.32.118.30  ipv4
# 3                                               "{}"            NaN   NaN
# 4  {'ip': '52.94.214.88', 'type': 'ipv4', 'contin...   52.94.214.88  ipv4
#
#   continent_code  ...                                 location.languages  \
# 0             NA  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 1             NA  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 2             NA  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 3            NaN  ...                                                NaN
# 4             NA  ...  [{'code': 'en', 'name': 'English', 'native': '...
#
#                      location.country_flag location.country_flag_emoji  \
# 0  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 1  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 2  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 3                                      NaN                         NaN
# 4  https://assets.ipstack.com/flags/us.svg                          🇺🇸
#
#   location.country_flag_emoji_unicode location.calling_code location.is_eu  \
# 0                     U+1F1FA U+1F1F8                     1          False
# 1                     U+1F1FA U+1F1F8                     1          False
# 2                     U+1F1FA U+1F1F8                     1          False
# 3                                 NaN                   NaN            NaN
# 4                     U+1F1FA U+1F1F8                     1          False
#
#   success  error.code  error.type  error.info
# 0     NaN         NaN         NaN         NaN
# 1     NaN         NaN         NaN         NaN
# 2     NaN         NaN         NaN         NaN
# 3     NaN         NaN         NaN         NaN
# 4     NaN         NaN         NaN         NaN
#
# [5 rows x 31 columns]

# %%
# Only consider successfully geo-resolved datacenter endpoints
df_result_nonna = df_result[df_result['latitude'].notna()]

# %%
df_result_nonna.head()
# Out:
#                                    Endpoint Provider          State  \
# 0  https://ec2.us-east-1.amazonaws.com/ping      AWS    N. Virginia
# 1  https://ec2.us-east-2.amazonaws.com/ping      AWS           Ohio
# 2  https://ec2.us-west-1.amazonaws.com/ping      AWS  N. California
# 4  https://ec2.us-west-2.amazonaws.com/ping      AWS         Oregon
# 5  https://ec2.ap-east-1.amazonaws.com/ping      AWS      Hong Kong
#
#             City        Country             IP  \
# 0        Ashburn  United States   52.46.142.79
# 1       Columbus  United States  99.78.176.246
# 2  San Francisco  United States  176.32.118.30
# 4       Portland  United States   52.94.214.88
# 5      Hong Kong      Hong Kong  13.248.32.123
#
#                                         geo_response             ip  type  \
# 0  {'ip': '52.46.142.79', 'type': 'ipv4', 'contin...   52.46.142.79  ipv4
# 1  {'ip': '99.78.176.246', 'type': 'ipv4', 'conti...  99.78.176.246  ipv4
# 2  {'ip': '176.32.118.30', 'type': 'ipv4', 'conti...  176.32.118.30  ipv4
# 4  {'ip': '52.94.214.88', 'type': 'ipv4', 'contin...   52.94.214.88  ipv4
# 5  {'ip': '13.248.32.123', 'type': 'ipv4', 'conti...  13.248.32.123  ipv4
#
#   continent_code  ...                                 location.languages  \
# 0             NA  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 1             NA  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 2             NA  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 4             NA  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 5             AS  ...  [{'code': 'zh', 'name': 'Chinese', 'native': '...
#
#                      location.country_flag location.country_flag_emoji  \
# 0  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 1  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 2  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 4  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 5  https://assets.ipstack.com/flags/hk.svg                          🇭🇰
#
#   location.country_flag_emoji_unicode location.calling_code location.is_eu  \
# 0                     U+1F1FA U+1F1F8                     1          False
# 1                     U+1F1FA U+1F1F8                     1          False
# 2                     U+1F1FA U+1F1F8                     1          False
# 4                     U+1F1FA U+1F1F8                     1          False
# 5                     U+1F1ED U+1F1F0                   852          False
#
#   success  error.code  error.type  error.info
# 0     NaN         NaN         NaN         NaN
# 1     NaN         NaN         NaN         NaN
# 2     NaN         NaN         NaN         NaN
# 4     NaN         NaN         NaN         NaN
# 5     NaN         NaN         NaN         NaN
#
# [5 rows x 31 columns]

# %%
# Prepare a map
map_center = [df_result_nonna['latitude'].mean(), df_result_nonna['longitude'].mean()]
map_object = folium.Map(location=map_center, zoom_start=5)

# %%
# Add markers for each row in the DataFrame
for index, row in df_result_nonna.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Endpoint']
    ).add_to(map_object)

map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b47cdd3ff6d2e96faa6bb1efedca976b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b47cdd3ff6d2e96faa6bb1efedca976b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b47cdd3ff6d2e96faa6bb1efedca976b = L.map(
#                 &quot;map_b47cdd3ff6d2e96faa6bb1efedca976b&quot;,
#                 {
#                     center: [25.957980188992945, 30.537745338265257],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_514539330ee675ca88b770bc7818fbea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_514539330ee675ca88b770bc7818fbea.addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#             var marker_a9cec871770b8e9cbc6f6f0071a8a08f = L.marker(
#                 [39.043701171875, -77.47419738769531],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_24f5590bf9748e7f18c5e5f0a09c3fa3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9822703b3b1872ea69b398f1536780a7 = $(`&lt;div id=&quot;html_9822703b3b1872ea69b398f1536780a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_24f5590bf9748e7f18c5e5f0a09c3fa3.setContent(html_9822703b3b1872ea69b398f1536780a7);
#
#
#
#         marker_a9cec871770b8e9cbc6f6f0071a8a08f.bindPopup(popup_24f5590bf9748e7f18c5e5f0a09c3fa3)
#         ;
#
#
#
#
#             var marker_28d23e1865196b9fd4e1a72c560f666a = L.marker(
#                 [39.99557876586914, -82.99945831298828],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_6eb0f9e412b97f93430d23842ebc7c88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae51b3e46daa3f7cd088634b0931ed73 = $(`&lt;div id=&quot;html_ae51b3e46daa3f7cd088634b0931ed73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-east-2.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_6eb0f9e412b97f93430d23842ebc7c88.setContent(html_ae51b3e46daa3f7cd088634b0931ed73);
#
#
#
#         marker_28d23e1865196b9fd4e1a72c560f666a.bindPopup(popup_6eb0f9e412b97f93430d23842ebc7c88)
#         ;
#
#
#
#
#             var marker_dc69cb3c088b8729067808e9cd9029c5 = L.marker(
#                 [37.330528259277344, -121.83822631835938],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_0ceb254e684f1cc3ce8f79da13e931b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00f42d18b5bdd39973bcfb512458ab70 = $(`&lt;div id=&quot;html_00f42d18b5bdd39973bcfb512458ab70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-west-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_0ceb254e684f1cc3ce8f79da13e931b5.setContent(html_00f42d18b5bdd39973bcfb512458ab70);
#
#
#
#         marker_dc69cb3c088b8729067808e9cd9029c5.bindPopup(popup_0ceb254e684f1cc3ce8f79da13e931b5)
#         ;
#
#
#
#
#             var marker_966443c3262b14ed20019a793fddc311 = L.marker(
#                 [45.83599853515625, -119.6989974975586],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_4170a3c369c700c4fa20c7d966dce941 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ebedb54dc9e73bcab485ce84a4e185e = $(`&lt;div id=&quot;html_3ebedb54dc9e73bcab485ce84a4e185e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-west-2.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_4170a3c369c700c4fa20c7d966dce941.setContent(html_3ebedb54dc9e73bcab485ce84a4e185e);
#
#
#
#         marker_966443c3262b14ed20019a793fddc311.bindPopup(popup_4170a3c369c700c4fa20c7d966dce941)
#         ;
#
#
#
#
#             var marker_7a2c7eee8ed962c00b1f43cb08f93cdd = L.marker(
#                 [22.248310089111328, 114.15239715576172],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_306a2f3ca2f2c4478456aa2247bd926c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6617215f76623b7247d6e7d0e4bb4388 = $(`&lt;div id=&quot;html_6617215f76623b7247d6e7d0e4bb4388&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.ap-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_306a2f3ca2f2c4478456aa2247bd926c.setContent(html_6617215f76623b7247d6e7d0e4bb4388);
#
#
#
#         marker_7a2c7eee8ed962c00b1f43cb08f93cdd.bindPopup(popup_306a2f3ca2f2c44784

# %%
df_result_nonna.to_csv('cloud_regions_geocoded.csv')

# %%
# Extract latitude and longitude columns for clustering
coordinates = df_result_nonna[['latitude', 'longitude']]
# Choose the number of clusters (k)
k = 50
# Perform k-means clustering
kmeans = KMeans(n_clusters=k, random_state=42)
df_result_nonna['cluster'] = kmeans.fit_predict(coordinates)
# Out:
# /var/folders/sg/vb52j6vx5gxgln4xc69djkp80000gn/T/ipykernel_9473/4156875325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_result_nonna['cluster'] = kmeans.fit_predict(coordinates)

# %%
df_result_nonna.head()
# Out:
#                                    Endpoint Provider          State  \
# 0  https://ec2.us-east-1.amazonaws.com/ping      AWS    N. Virginia
# 1  https://ec2.us-east-2.amazonaws.com/ping      AWS           Ohio
# 2  https://ec2.us-west-1.amazonaws.com/ping      AWS  N. California
# 4  https://ec2.us-west-2.amazonaws.com/ping      AWS         Oregon
# 5  https://ec2.ap-east-1.amazonaws.com/ping      AWS      Hong Kong
#
#             City        Country             IP  \
# 0        Ashburn  United States   52.46.142.79
# 1       Columbus  United States  99.78.176.246
# 2  San Francisco  United States  176.32.118.30
# 4       Portland  United States   52.94.214.88
# 5      Hong Kong      Hong Kong  13.248.32.123
#
#                                         geo_response             ip  type  \
# 0  {'ip': '52.46.142.79', 'type': 'ipv4', 'contin...   52.46.142.79  ipv4
# 1  {'ip': '99.78.176.246', 'type': 'ipv4', 'conti...  99.78.176.246  ipv4
# 2  {'ip': '176.32.118.30', 'type': 'ipv4', 'conti...  176.32.118.30  ipv4
# 4  {'ip': '52.94.214.88', 'type': 'ipv4', 'contin...   52.94.214.88  ipv4
# 5  {'ip': '13.248.32.123', 'type': 'ipv4', 'conti...  13.248.32.123  ipv4
#
#   continent_code  ...                    location.country_flag  \
# 0             NA  ...  https://assets.ipstack.com/flags/us.svg
# 1             NA  ...  https://assets.ipstack.com/flags/us.svg
# 2             NA  ...  https://assets.ipstack.com/flags/us.svg
# 4             NA  ...  https://assets.ipstack.com/flags/us.svg
# 5             AS  ...  https://assets.ipstack.com/flags/hk.svg
#
#   location.country_flag_emoji location.country_flag_emoji_unicode  \
# 0                          🇺🇸                     U+1F1FA U+1F1F8
# 1                          🇺🇸                     U+1F1FA U+1F1F8
# 2                          🇺🇸                     U+1F1FA U+1F1F8
# 4                          🇺🇸                     U+1F1FA U+1F1F8
# 5                          🇭🇰                     U+1F1ED U+1F1F0
#
#   location.calling_code location.is_eu success error.code  error.type  \
# 0                     1          False     NaN        NaN         NaN
# 1                     1          False     NaN        NaN         NaN
# 2                     1          False     NaN        NaN         NaN
# 4                     1          False     NaN        NaN         NaN
# 5                   852          False     NaN        NaN         NaN
#
#    error.info  cluster
# 0         NaN       37
# 1         NaN       31
# 2         NaN       22
# 4         NaN       38
# 5         NaN        9
#
# [5 rows x 32 columns]

# %%
colors = [
    'red',
    'blue',
    'gray',
    'darkred',
    'lightred',
    'orange',
    'beige',
    'green',
    'darkgreen',
    'lightgreen',
    'darkblue',
    'lightblue',
    'purple',
    'darkpurple',
    'pink',
    'cadetblue',
    'lightgray',
    'black'
]

map_center = [df_result_nonna['latitude'].mean(), df_result_nonna['longitude'].mean()]
map_object = folium.Map(location=map_center, zoom_start=5)

# Add markers for each row in the DataFrame
for index, row in df_result_nonna.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Endpoint'],
        icon=folium.Icon(color=colors[row['cluster'] % len(colors)])
    ).add_to(map_object)

map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b47cdd3ff6d2e96faa6bb1efedca976b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b47cdd3ff6d2e96faa6bb1efedca976b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b47cdd3ff6d2e96faa6bb1efedca976b = L.map(
#                 &quot;map_b47cdd3ff6d2e96faa6bb1efedca976b&quot;,
#                 {
#                     center: [25.957980188992945, 30.537745338265257],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_514539330ee675ca88b770bc7818fbea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_514539330ee675ca88b770bc7818fbea.addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#             var marker_a9cec871770b8e9cbc6f6f0071a8a08f = L.marker(
#                 [39.043701171875, -77.47419738769531],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_24f5590bf9748e7f18c5e5f0a09c3fa3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9822703b3b1872ea69b398f1536780a7 = $(`&lt;div id=&quot;html_9822703b3b1872ea69b398f1536780a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_24f5590bf9748e7f18c5e5f0a09c3fa3.setContent(html_9822703b3b1872ea69b398f1536780a7);
#
#
#
#         marker_a9cec871770b8e9cbc6f6f0071a8a08f.bindPopup(popup_24f5590bf9748e7f18c5e5f0a09c3fa3)
#         ;
#
#
#
#
#             var marker_28d23e1865196b9fd4e1a72c560f666a = L.marker(
#                 [39.99557876586914, -82.99945831298828],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_6eb0f9e412b97f93430d23842ebc7c88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae51b3e46daa3f7cd088634b0931ed73 = $(`&lt;div id=&quot;html_ae51b3e46daa3f7cd088634b0931ed73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-east-2.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_6eb0f9e412b97f93430d23842ebc7c88.setContent(html_ae51b3e46daa3f7cd088634b0931ed73);
#
#
#
#         marker_28d23e1865196b9fd4e1a72c560f666a.bindPopup(popup_6eb0f9e412b97f93430d23842ebc7c88)
#         ;
#
#
#
#
#             var marker_dc69cb3c088b8729067808e9cd9029c5 = L.marker(
#                 [37.330528259277344, -121.83822631835938],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_0ceb254e684f1cc3ce8f79da13e931b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00f42d18b5bdd39973bcfb512458ab70 = $(`&lt;div id=&quot;html_00f42d18b5bdd39973bcfb512458ab70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-west-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_0ceb254e684f1cc3ce8f79da13e931b5.setContent(html_00f42d18b5bdd39973bcfb512458ab70);
#
#
#
#         marker_dc69cb3c088b8729067808e9cd9029c5.bindPopup(popup_0ceb254e684f1cc3ce8f79da13e931b5)
#         ;
#
#
#
#
#             var marker_966443c3262b14ed20019a793fddc311 = L.marker(
#                 [45.83599853515625, -119.6989974975586],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_4170a3c369c700c4fa20c7d966dce941 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ebedb54dc9e73bcab485ce84a4e185e = $(`&lt;div id=&quot;html_3ebedb54dc9e73bcab485ce84a4e185e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.us-west-2.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_4170a3c369c700c4fa20c7d966dce941.setContent(html_3ebedb54dc9e73bcab485ce84a4e185e);
#
#
#
#         marker_966443c3262b14ed20019a793fddc311.bindPopup(popup_4170a3c369c700c4fa20c7d966dce941)
#         ;
#
#
#
#
#             var marker_7a2c7eee8ed962c00b1f43cb08f93cdd = L.marker(
#                 [22.248310089111328, 114.15239715576172],
#                 {}
#             ).addTo(map_b47cdd3ff6d2e96faa6bb1efedca976b);
#
#
#         var popup_306a2f3ca2f2c4478456aa2247bd926c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6617215f76623b7247d6e7d0e4bb4388 = $(`&lt;div id=&quot;html_6617215f76623b7247d6e7d0e4bb4388&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.ap-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_306a2f3ca2f2c4478456aa2247bd926c.setContent(html_6617215f76623b7247d6e7d0e4bb4388);
#
#
#
#         marker_7a2c7eee8ed962c00b1f43cb08f93cdd.bindPopup(popup_306a2f3ca2f2c44784

# %%
# Group by cluster and provider, and select unique rows for each group
unique_rows_by_cluster = df_result_nonna.groupby(['cluster', 'Provider']).first().reset_index()

# %%
unique_rows_by_cluster.head(10)
# Out:
#    cluster Provider                                           Endpoint  \
# 0        0    Vultr                       https://wa-us-ping.vultr.com
# 1        1   UCloud    https://feitsui-bjs.cn-bj.ufileos.com/ping.html
# 2        2      AWS          https://ec2.eu-south-1.amazonaws.com/ping
# 3        3      AWS           https://ec2.sa-east-1.amazonaws.com/ping
# 4        3  Tencent  https://feitsui-gru-1251417183.cos.sa-saopaulo...
# 5        4      AWS      https://ec2.ap-southeast-3.amazonaws.com/ping
# 6        4  Alibaba  https://feitsui-cgk.oss-ap-southeast-5.aliyunc...
# 7        4  Tencent  https://feitsui-cgk-1251417183.cos.ap-jakarta....
# 8        5   Linode              https://speedtest.atlanta.linode.com/
# 9        5    Vultr                       https://ga-us-ping.vultr.com
#
#           State       City        Country              IP  \
# 0            WA    Seattle  United States  108.61.194.105
# 1         cn-bj    Beijing          China   117.50.123.29
# 2         Milan      Milan          Italy   52.119.132.74
# 3     São Paulo  São Paulo         Brazil  177.72.245.165
# 4       Unknown  Sao Paulo         Brazil   43.157.144.10
# 5       Jakarta    Jakarta      Indonesia   99.78.244.123
# 6       Jakarta    Jakarta      Indonesia  149.129.200.34
# 7       Unknown    Jakarta      Indonesia   43.129.45.240
# 8  US Southeast    Atlanta      Southeast  192.155.94.157
# 9            GA    Atlanta  United States  108.61.193.166
#
#                                         geo_response              ip  type  \
# 0  {'ip': '108.61.194.105', 'type': 'ipv4', 'cont...  108.61.194.105  ipv4
# 1  {'ip': '117.50.123.29', 'type': 'ipv4', 'conti...   117.50.123.29  ipv4
# 2  {'ip': '52.119.132.74', 'type': 'ipv4', 'conti...   52.119.132.74  ipv4
# 3  {'ip': '177.72.245.165', 'type': 'ipv4', 'cont...  177.72.245.165  ipv4
# 4  {'ip': '43.157.144.10', 'type': 'ipv4', 'conti...   43.157.144.10  ipv4
# 5  {'ip': '99.78.244.123', 'type': 'ipv4', 'conti...   99.78.244.123  ipv4
# 6  {'ip': '149.129.200.34', 'type': 'ipv4', 'cont...  149.129.200.34  ipv4
# 7  {'ip': '43.129.45.240', 'type': 'ipv4', 'conti...   43.129.45.240  ipv4
# 8  {'ip': '192.155.94.157', 'type': 'ipv4', 'cont...  192.155.94.157  ipv4
# 9  {'ip': '108.61.193.166', 'type': 'ipv4', 'cont...  108.61.193.166  ipv4
#
#    ...                                 location.languages  \
# 0  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 1  ...  [{'code': 'zh', 'name': 'Chinese', 'native': '...
# 2  ...  [{'code': 'it', 'name': 'Italian', 'native': '...
# 3  ...  [{'code': 'pt', 'name': 'Portuguese', 'native'...
# 4  ...  [{'code': 'pt', 'name': 'Portuguese', 'native'...
# 5  ...  [{'code': 'id', 'name': 'Indonesian', 'native'...
# 6  ...  [{'code': 'id', 'name': 'Indonesian', 'native'...
# 7  ...  [{'code': 'id', 'name': 'Indonesian', 'native'...
# 8  ...  [{'code': 'en', 'name': 'English', 'native': '...
# 9  ...  [{'code': 'en', 'name': 'English', 'native': '...
#
#                      location.country_flag location.country_flag_emoji  \
# 0  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 1  https://assets.ipstack.com/flags/cn.svg                          🇨🇳
# 2  https://assets.ipstack.com/flags/it.svg                          🇮🇹
# 3  https://assets.ipstack.com/flags/br.svg                          🇧🇷
# 4  https://assets.ipstack.com/flags/br.svg                          🇧🇷
# 5  https://assets.ipstack.com/flags/id.svg                          🇮🇩
# 6  https://assets.ipstack.com/flags/id.svg                          🇮🇩
# 7  https://assets.ipstack.com/flags/id.svg                          🇮🇩
# 8  https://assets.ipstack.com/flags/us.svg                          🇺🇸
# 9  https://assets.ipstack.com/flags/us.svg                          🇺🇸
#
#   location.country_flag_emoji_unicode location.calling_code location.is_eu  \
# 0                     U+1F1FA U+1F1F8                     1          False
# 1                     U+1F1E8 U+1F1F3                    86          False
# 2                     U+1F1EE U+1F1F9                    39           True
# 3                     U+1F1E7 U+1F1F7                    55          False
# 4                     U+1F1E7 U+1F1F7                    55          False
# 5                     U+1F1EE U+1F1E9                    62          False
# 6                     U+1F1EE U+1F1E9                    62          False
# 7                     U+1F1EE U+1F1E9                    62          False
# 8                     U+1F1FA U+1F1F8                     1          False
# 9                     U+1F1FA U+1F1F8                     1          False
#
#   success error.code  error.type  error.info
# 0    None        NaN        None        None
# 1    None        NaN        None        None
# 2    None        NaN        None        None
# 3    None        NaN        None        None
# 4    None        NaN        None        None
# 5    None        NaN        None        None
# 6    None        NaN        None        None
# 7    None        NaN        None        None
# 8    None        NaN        None        None
# 9    None        NaN        None        None
#
# [10 rows x 32 columns]

# %%
map_center = [unique_rows_by_cluster['latitude'].mean(), unique_rows_by_cluster['longitude'].mean()]
map_object = folium.Map(location=map_center, zoom_start=5)

for index, row in unique_rows_by_cluster.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Endpoint']
    ).add_to(map_object)
    
map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67cf04886b22ed703899b331fdb3b6e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67cf04886b22ed703899b331fdb3b6e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67cf04886b22ed703899b331fdb3b6e9 = L.map(
#                 &quot;map_67cf04886b22ed703899b331fdb3b6e9&quot;,
#                 {
#                     center: [26.61946621502147, 20.384890123675852],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cbd014e8774d754658cfba4ccc9e420 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2cbd014e8774d754658cfba4ccc9e420.addTo(map_67cf04886b22ed703899b331fdb3b6e9);
#
#
#             var marker_0e3740e93067c6a5afd2a7d3ace45cdf = L.marker(
#                 [47.36235809326172, -122.19828033447266],
#                 {}
#             ).addTo(map_67cf04886b22ed703899b331fdb3b6e9);
#
#
#         var popup_6b94052ee6427f7ba71d6b81157cfc23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3a71a859abac29719795d48b97ff4fb = $(`&lt;div id=&quot;html_c3a71a859abac29719795d48b97ff4fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://wa-us-ping.vultr.com&lt;/div&gt;`)[0];
#                 popup_6b94052ee6427f7ba71d6b81157cfc23.setContent(html_c3a71a859abac29719795d48b97ff4fb);
#
#
#
#         marker_0e3740e93067c6a5afd2a7d3ace45cdf.bindPopup(popup_6b94052ee6427f7ba71d6b81157cfc23)
#         ;
#
#
#
#
#             var marker_062fa40eae276d5224184544ca3c6a02 = L.marker(
#                 [31.228469848632812, 121.47020721435547],
#                 {}
#             ).addTo(map_67cf04886b22ed703899b331fdb3b6e9);
#
#
#         var popup_06ac6b147084c688fa7be2dcb686b0ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4c458c7e6596bd9f637c5c9afa01030 = $(`&lt;div id=&quot;html_c4c458c7e6596bd9f637c5c9afa01030&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://feitsui-bjs.cn-bj.ufileos.com/ping.html&lt;/div&gt;`)[0];
#                 popup_06ac6b147084c688fa7be2dcb686b0ea.setContent(html_c4c458c7e6596bd9f637c5c9afa01030);
#
#
#
#         marker_062fa40eae276d5224184544ca3c6a02.bindPopup(popup_06ac6b147084c688fa7be2dcb686b0ea)
#         ;
#
#
#
#
#             var marker_1f0682dff661e47db1e71f0efcb1099f = L.marker(
#                 [45.465999603271484, 9.186670303344727],
#                 {}
#             ).addTo(map_67cf04886b22ed703899b331fdb3b6e9);
#
#
#         var popup_6145eadd3ee6eb366a6dbce051144b5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a56ca6307b4ac6ff52d954b170e4bb0 = $(`&lt;div id=&quot;html_7a56ca6307b4ac6ff52d954b170e4bb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.eu-south-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_6145eadd3ee6eb366a6dbce051144b5e.setContent(html_7a56ca6307b4ac6ff52d954b170e4bb0);
#
#
#
#         marker_1f0682dff661e47db1e71f0efcb1099f.bindPopup(popup_6145eadd3ee6eb366a6dbce051144b5e)
#         ;
#
#
#
#
#             var marker_a8f242a2c4c4d6bf36252a6e975215f5 = L.marker(
#                 [-23.547500610351562, -46.6361083984375],
#                 {}
#             ).addTo(map_67cf04886b22ed703899b331fdb3b6e9);
#
#
#         var popup_eb805fba1d8572e99dff786c46d28bf4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d52d09e058a485001fcad0f0217fd220 = $(`&lt;div id=&quot;html_d52d09e058a485001fcad0f0217fd220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://ec2.sa-east-1.amazonaws.com/ping&lt;/div&gt;`)[0];
#                 popup_eb805fba1d8572e99dff786c46d28bf4.setContent(html_d52d09e058a485001fcad0f0217fd220);
#
#
#
#         marker_a8f242a2c4c4d6bf36252a6e975215f5.bindPopup(popup_eb805fba1d8572e99dff786c46d28bf4)
#         ;
#
#
#
#
#             var marker_ca877ba535e189a9065a05e8d23f5558 = L.marker(
#                 [-23.547500610351562, -46.6361083984375],
#                 {}
#             ).addTo(map_67cf04886b22ed703899b331fdb3b6e9);
#
#
#         var popup_266f312c74b0eaa011ffe99ef5bc2732 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb0a560f7e7f7a7477c7930c697ce4ea = $(`&lt;div id=&quot;html_bb0a560f7e7f7a7477c7930c697ce4ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;https://feitsui-gru-1251417183.cos.sa-saopaulo.myqcloud.com/ping.html&lt;/div&gt;`)[0];
#                 popup_266f312c74b0eaa011ffe99ef5bc2732.setContent(html_bb0a560f7e7f7a7477c7930c697ce4ea);
#
#
#
#         marker_ca877ba535e189a9065a05e8d23f5558.bindPop

# %%
unique_rows_by_cluster.to_csv('cloud_endpoints_final.csv')

# %%
# Here we work with unpacked .json files from the latest probe dataset (2024)
# We unpacked them by running: find 2024 -type f -name "*.bz2" -exec bzip2 -dk {} \;
file_path = '2024/02/20240209.json'

with open(file_path, 'r') as f:
    data = json.load(f)
    df_probes = pd.DataFrame(data['objects'])

# %%
df_probes.head()
# Out:
#    id      address_v4                           address_v6    asn_v4  \
# 0   1   45.138.229.91   2a10:3781:e22:1:220:4aff:fec8:23d7  206238.0
# 1   2            None                                 None    1136.0
# 2   3    77.174.76.85  2a02:a467:f500:1:220:4aff:fec8:2532    1136.0
# 3   4   83.163.50.165   2001:980:57a4:1:220:4aff:fec8:244a    3265.0
# 4   5  83.163.239.181   2001:981:602b:1:220:4aff:fec8:2355    3265.0
#
#      asn_v6        prefix_v4       prefix_v6  is_anchor  is_public  status  \
# 0  206238.0  45.138.228.0/22  2a10:3780::/29      False       True       1
# 1    1136.0    77.160.0.0/13  2a02:a400::/25      False      False       3
# 2    1136.0    77.174.0.0/16  2a02:a400::/25      False       True       1
# 3    3265.0    83.160.0.0/14   2001:980::/32      False       True       3
# 4    3265.0    83.160.0.0/14   2001:980::/30      False       True       3
#
#    status_since  first_connected  total_uptime  \
# 0    1707269398     1.288368e+09     407264862
# 1    1640571508     1.288385e+09     347389948
# 2    1706618589     1.288373e+09     403591652
# 3    1568319241     1.288599e+09     248928764
# 4    1513671789     1.288600e+09     185731720
#
#                                                 tags country_code  latitude  \
# 0  [system-ipv4-stable-1d, system-resolves-aaaa-c...           NL   52.3475
# 1  [system-no-controller-connection, system-ipv6-...           GU   42.6585
# 2  [system-ipv6-stable-1d, system-firewall-proble...           NL   52.3685
# 3  [dsl, home, system-v1, iwantbcp38compliancetes...           NL   52.3895
# 4  [home, nat, system-v1, system-ipv4-capable, sy...           ES   36.8295
#
#    longitude       day                                    probe status_name
# 0     4.9275  20240209  https://atlas.ripe.net/api/v2/probes/1/   Connected
# 1    21.1575  20240209  https://atlas.ripe.net/api/v2/probes/2/   Abandoned
# 2     4.9375  20240209  https://atlas.ripe.net/api/v2/probes/3/   Connected
# 3     4.6375  20240209  https://atlas.ripe.net/api/v2/probes/4/   Abandoned
# 4    -2.4625  20240209  https://atlas.ripe.net/api/v2/probes/5/   Abandoned

# %%
df_probes_filtered = df_probes
df_probes_filtered['tags'] = df_probes['tags'].apply(set)
df_probes_filtered = df_probes_filtered[df_probes_filtered['tags'].apply(lambda tags: 'system-ipv4-stable-1d' in tags)]
df_probes_filtered = df_probes_filtered[df_probes_filtered['status'] == 1]

# %%
df_probes_filtered.head()
# Out:
#     id     address_v4                              address_v6    asn_v4  \
# 0    1  45.138.229.91      2a10:3781:e22:1:220:4aff:fec8:23d7  206238.0
# 7    8   83.81.83.145  2001:1c05:2011:fa00:220:4aff:fec8:2464   33915.0
# 13  14  79.55.209.251                                    None    3269.0
# 29  30           None                                    None   20115.0
# 31  32   76.82.152.84  2603:8001:5000:2aa0:220:4aff:fec8:25ed   20001.0
#
#       asn_v6        prefix_v4       prefix_v6  is_anchor  is_public  status  \
# 0   206238.0  45.138.228.0/22  2a10:3780::/29      False       True       1
# 7    33915.0     83.80.0.0/14  2001:1c00::/24      False       True       1
# 13       NaN     79.55.0.0/16            None      False       True       1
# 29       NaN   75.142.96.0/19            None      False      False       1
# 31   20001.0     76.80.0.0/14  2603:8000::/28      False       True       1
#
#     status_since  first_connected  total_uptime  \
# 0     1707269398     1.288368e+09     407264862
# 7     1706383318     1.288619e+09     405485386
# 13    1706621509     1.289551e+09     352983358
# 29    1706400797     1.290200e+09     170845189
# 31    1707134284     1.289868e+09     406671689
#
#                                                  tags country_code  latitude  \
# 0   {system-ipv4-stable-30d, home, system-ipv4-rfc...           NL   52.3475
# 7   {ziggo, system-ipv4-stable-30d, home, system-i...           NL   51.1915
# 13  {system-v1, system-ipv4-stable-30d, system-ipv...           IT   41.8995
# 29  {system-v1, system-ipv4-stable-30d, home, syst...           US   33.8175
# 31  {system-ipv4-stable-30d, home, system-ipv4-rfc...           US   32.8885
#
#     longitude       day                                     probe status_name
# 0      4.9275  20240209   https://atlas.ripe.net/api/v2/probes/1/   Connected
# 7      5.9975  20240209   https://atlas.ripe.net/api/v2/probes/8/   Connected
# 13    12.4375  20240209  https://atlas.ripe.net/api/v2/probes/14/   Connected
# 29  -118.0615  20240209  https://atlas.ripe.net/api/v2/probes/30/   Connected
# 31  -117.1815  20240209  https://atlas.ripe.net/api/v2/probes/32/   Connected

# %%
df_probes_filtered.head()
# Out:
#     id     address_v4                              address_v6    asn_v4  \
# 0    1  45.138.229.91      2a10:3781:e22:1:220:4aff:fec8:23d7  206238.0
# 7    8   83.81.83.145  2001:1c05:2011:fa00:220:4aff:fec8:2464   33915.0
# 13  14  79.55.209.251                                    None    3269.0
# 29  30           None                                    None   20115.0
# 31  32   76.82.152.84  2603:8001:5000:2aa0:220:4aff:fec8:25ed   20001.0
#
#       asn_v6        prefix_v4       prefix_v6  is_anchor  is_public  status  \
# 0   206238.0  45.138.228.0/22  2a10:3780::/29      False       True       1
# 7    33915.0     83.80.0.0/14  2001:1c00::/24      False       True       1
# 13       NaN     79.55.0.0/16            None      False       True       1
# 29       NaN   75.142.96.0/19            None      False      False       1
# 31   20001.0     76.80.0.0/14  2603:8000::/28      False       True       1
#
#     status_since  first_connected  total_uptime  \
# 0     1707269398     1.288368e+09     407264862
# 7     1706383318     1.288619e+09     405485386
# 13    1706621509     1.289551e+09     352983358
# 29    1706400797     1.290200e+09     170845189
# 31    1707134284     1.289868e+09     406671689
#
#                                                  tags country_code  latitude  \
# 0   {system-ipv4-stable-30d, home, system-ipv4-rfc...           NL   52.3475
# 7   {ziggo, system-ipv4-stable-30d, home, system-i...           NL   51.1915
# 13  {system-v1, system-ipv4-stable-30d, system-ipv...           IT   41.8995
# 29  {system-v1, system-ipv4-stable-30d, home, syst...           US   33.8175
# 31  {system-ipv4-stable-30d, home, system-ipv4-rfc...           US   32.8885
#
#     longitude       day                                     probe status_name
# 0      4.9275  20240209   https://atlas.ripe.net/api/v2/probes/1/   Connected
# 7      5.9975  20240209   https://atlas.ripe.net/api/v2/probes/8/   Connected
# 13    12.4375  20240209  https://atlas.ripe.net/api/v2/probes/14/   Connected
# 29  -118.0615  20240209  https://atlas.ripe.net/api/v2/probes/30/   Connected
# 31  -117.1815  20240209  https://atlas.ripe.net/api/v2/probes/32/   Connected

# %%
total_probes = 300

continent_population_share = {
    'NA': 7.5,
    'SA': 5.5, 
    'AS': 59.4,
    'OC': 0.6,
    'AF': 17.6,
    'EU': 9.4
}

def country_to_continent(country_code):
    try:
        return pc.country_alpha2_to_continent_code(country_code)
    except KeyError:
        return None

# %%
df_probes_filtered['continent'] = df_probes_filtered['country_code'].apply(country_to_continent)

# %%
df_probes_filtered.head()
# Out:
#     id     address_v4                              address_v6    asn_v4  \
# 0    1  45.138.229.91      2a10:3781:e22:1:220:4aff:fec8:23d7  206238.0
# 7    8   83.81.83.145  2001:1c05:2011:fa00:220:4aff:fec8:2464   33915.0
# 13  14  79.55.209.251                                    None    3269.0
# 29  30           None                                    None   20115.0
# 31  32   76.82.152.84  2603:8001:5000:2aa0:220:4aff:fec8:25ed   20001.0
#
#       asn_v6        prefix_v4       prefix_v6  is_anchor  is_public  status  \
# 0   206238.0  45.138.228.0/22  2a10:3780::/29      False       True       1
# 7    33915.0     83.80.0.0/14  2001:1c00::/24      False       True       1
# 13       NaN     79.55.0.0/16            None      False       True       1
# 29       NaN   75.142.96.0/19            None      False      False       1
# 31   20001.0     76.80.0.0/14  2603:8000::/28      False       True       1
#
#     ...  first_connected  total_uptime  \
# 0   ...     1.288368e+09     407264862
# 7   ...     1.288619e+09     405485386
# 13  ...     1.289551e+09     352983358
# 29  ...     1.290200e+09     170845189
# 31  ...     1.289868e+09     406671689
#
#                                                  tags country_code latitude  \
# 0   {system-ipv4-stable-30d, home, system-ipv4-rfc...           NL  52.3475
# 7   {ziggo, system-ipv4-stable-30d, home, system-i...           NL  51.1915
# 13  {system-v1, system-ipv4-stable-30d, system-ipv...           IT  41.8995
# 29  {system-v1, system-ipv4-stable-30d, home, syst...           US  33.8175
# 31  {system-ipv4-stable-30d, home, system-ipv4-rfc...           US  32.8885
#
#     longitude       day                                     probe status_name  \
# 0      4.9275  20240209   https://atlas.ripe.net/api/v2/probes/1/   Connected
# 7      5.9975  20240209   https://atlas.ripe.net/api/v2/probes/8/   Connected
# 13    12.4375  20240209  https://atlas.ripe.net/api/v2/probes/14/   Connected
# 29  -118.0615  20240209  https://atlas.ripe.net/api/v2/probes/30/   Connected
# 31  -117.1815  20240209  https://atlas.ripe.net/api/v2/probes/32/   Connected
#
#    continent
# 0         EU
# 7         EU
# 13        EU
# 29        NA
# 31        NA
#
# [5 rows x 21 columns]

# %%
print(country_to_continent('NL'))
# Out:
# EU

# %%
filters = {
    "radio (wi-fi)": lambda row: 'home' in row['tags'] and any(x in row['tags'] for x in {"wi-fi", "wifi", "wlan", "wireless", "wireless-isp", "wireless-link"}),
    "radio (mobile)": lambda row: any(x in row['tags'] for x in {"lte", "5g", "4g", "3g", "cellular"}),
    "satellite": lambda row: row["asn_v4"] == 14593,
    "ethernet": lambda row: 'home' in row['tags'] and any(x in row['tags'] for x in {"dsl", "adsl", "fibre", "fiber", "cable", "ftth"})
}

# %%
for filter_name, filter_func in filters.items():
    df_filtered_temp = df_probes_filtered[df_probes_filtered.apply(filter_func, axis=1)]
    print(filter_name, ": ", df_filtered_temp.shape)
# Out:
# radio (wi-fi) :  (65, 21)
# radio (mobile) :  (60, 21)
# satellite :  (11, 21)
# ethernet :  (1711, 21)
